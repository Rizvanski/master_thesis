# %%
######### Data Management File #########

# Data for Main Analysis

# %%
# Packages used

import numpy as np
import pandas as pd

# %%
# Indicator variables

# empty data frame
data_frame = pd.DataFrame()

# defining the countries of interest
balkan_countries = ["Albania", "North Macedonia", "Serbia", "Montenegro", "Bosnia and Herzegovina", "Croatia", "Slovenia", "Bulgaria", "Romania"]

# indicator variables (country, year)
data_frame["country"] = np.repeat(balkan_countries,17)
data_frame["year"] = np.tile(range(2000,2017),9).astype(int)

# %%
# Dependent variable SWIID Market Income Inequality

# loading the SWIID data
swiid = pd.read_stata("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/swiid_income_inequality.dta")


# selecting observations and calculating mean
selecting_data = swiid[swiid['country'].isin(balkan_countries) & (swiid['year'] >= 2000) & (swiid['year'] <= 2016)]
selecting_data["mrkt_inc"] = selecting_data.iloc[:, 104:204].mean(axis=1)

# adding new variable with NaN values
data_frame["swiid_market"] = np.nan

# Albania
data_frame.iloc[0:17,2] = selecting_data[selecting_data['country'] == 'Albania']['mrkt_inc']

# North Macedonia
data_frame.iloc[17:34,2] = selecting_data[selecting_data['country'] == 'North Macedonia']['mrkt_inc']

# Serbia
data_frame.iloc[34:51,2] = selecting_data[selecting_data['country'] == 'Serbia']['mrkt_inc']

# Montenegro
data_frame.iloc[56:68,2] = selecting_data[selecting_data['country'] == 'Montenegro']['mrkt_inc']

# Bosnia and Herzegovina
data_frame.iloc[69:84,2] = selecting_data[selecting_data['country'] == 'Bosnia and Herzegovina']['mrkt_inc']

# Croatia
data_frame.iloc[85:102,2] = selecting_data[selecting_data['country'] == 'Croatia']['mrkt_inc']

# Slovenia
data_frame.iloc[102:119,2] = selecting_data[selecting_data['country'] == 'Slovenia']['mrkt_inc']

# Bulgaria
data_frame.iloc[119:136,2] = selecting_data[selecting_data['country'] == 'Bulgaria']['mrkt_inc']

# Romania
data_frame.iloc[136:153,2] = selecting_data[selecting_data['country'] == 'Romania']['mrkt_inc']


# SWIID Market Income Inequality for bottom 50%
selecting_data["mrkt_inc1"] = selecting_data.iloc[:, 104:154].mean(axis=1)
# adding new variable with NaN values
data_frame["swiid_mrkt_bott50"] = np.nan

# Albania
data_frame.iloc[0:17,3] = selecting_data[selecting_data['country'] == 'Albania']['mrkt_inc1']

# North Macedonia
data_frame.iloc[17:34,3] = selecting_data[selecting_data['country'] == 'North Macedonia']['mrkt_inc1']

# Serbia
data_frame.iloc[34:51,3] = selecting_data[selecting_data['country'] == 'Serbia']['mrkt_inc1']

# Montenegro
data_frame.iloc[56:68,3] = selecting_data[selecting_data['country'] == 'Montenegro']['mrkt_inc1']

# Bosnia and Herzegovina
data_frame.iloc[69:84,3] = selecting_data[selecting_data['country'] == 'Bosnia and Herzegovina']['mrkt_inc1']

# Croatia
data_frame.iloc[85:102,3] = selecting_data[selecting_data['country'] == 'Croatia']['mrkt_inc1']

# Slovenia
data_frame.iloc[102:119,3] = selecting_data[selecting_data['country'] == 'Slovenia']['mrkt_inc1']

# Bulgaria
data_frame.iloc[119:136,3] = selecting_data[selecting_data['country'] == 'Bulgaria']['mrkt_inc1']

# Romania
data_frame.iloc[136:153,3] = selecting_data[selecting_data['country'] == 'Romania']['mrkt_inc1']


# SWIID Market Income Inequality for top 10%
selecting_data["mrkt_inc2"] = selecting_data.iloc[:, 194:204].mean(axis=1)
# adding new variable with NaN values
data_frame["swiid_mrkt_top10"] = np.nan

# Albania
data_frame.iloc[0:17,4] = selecting_data[selecting_data['country'] == 'Albania']['mrkt_inc2']

# North Macedonia
data_frame.iloc[17:34,4] = selecting_data[selecting_data['country'] == 'North Macedonia']['mrkt_inc2']

# Serbia
data_frame.iloc[34:51,4] = selecting_data[selecting_data['country'] == 'Serbia']['mrkt_inc2']

# Montenegro
data_frame.iloc[56:68,4] = selecting_data[selecting_data['country'] == 'Montenegro']['mrkt_inc2']

# Bosnia and Herzegovina
data_frame.iloc[69:84,4] = selecting_data[selecting_data['country'] == 'Bosnia and Herzegovina']['mrkt_inc2']

# Croatia
data_frame.iloc[85:102,4] = selecting_data[selecting_data['country'] == 'Croatia']['mrkt_inc2']

# Slovenia
data_frame.iloc[102:119,4] = selecting_data[selecting_data['country'] == 'Slovenia']['mrkt_inc2']

# Bulgaria
data_frame.iloc[119:136,4] = selecting_data[selecting_data['country'] == 'Bulgaria']['mrkt_inc2']

# Romania
data_frame.iloc[136:153,4] = selecting_data[selecting_data['country'] == 'Romania']['mrkt_inc2']


# Dependent variable SWIID Disposable Income Inequality

# selecting observations and calculating mean
selecting_data["dsp_inc"] = selecting_data.iloc[:, 3:103].mean(axis=1)
# adding new variable with NaN values
data_frame["swiid_dsp"] = np.nan

# Albania
data_frame.iloc[0:17,5] = selecting_data[selecting_data['country'] == 'Albania']['dsp_inc']

# North Macedonia
data_frame.iloc[17:34,5] = selecting_data[selecting_data['country'] == 'North Macedonia']['dsp_inc']

# Serbia
data_frame.iloc[34:51,5] = selecting_data[selecting_data['country'] == 'Serbia']['dsp_inc']

# Montenegro
data_frame.iloc[56:68,5] = selecting_data[selecting_data['country'] == 'Montenegro']['dsp_inc']

# Bosnia and Herzegovina
data_frame.iloc[69:84,5] = selecting_data[selecting_data['country'] == 'Bosnia and Herzegovina']['dsp_inc']

# Croatia
data_frame.iloc[85:102,5] = selecting_data[selecting_data['country'] == 'Croatia']['dsp_inc']

# Slovenia
data_frame.iloc[102:119,5] = selecting_data[selecting_data['country'] == 'Slovenia']['dsp_inc']

# Bulgaria
data_frame.iloc[119:136,5] = selecting_data[selecting_data['country'] == 'Bulgaria']['dsp_inc']

# Romania
data_frame.iloc[136:153,5] = selecting_data[selecting_data['country'] == 'Romania']['dsp_inc']


# SWIID Disposable Income Inequality for the bottom 50%

# selecting observations and calculating mean
selecting_data["dsp_inc50"] = selecting_data.iloc[:, 3:53].mean(axis=1)
# adding new variable with NaN values
data_frame["swiid_dsp_bott50"] = np.nan

# Albania
data_frame.iloc[0:17,6] = selecting_data[selecting_data['country'] == 'Albania']['dsp_inc50']

# North Macedonia
data_frame.iloc[17:34,6] = selecting_data[selecting_data['country'] == 'North Macedonia']['dsp_inc50']

# Serbia
data_frame.iloc[34:51,6] = selecting_data[selecting_data['country'] == 'Serbia']['dsp_inc50']

# Montenegro
data_frame.iloc[56:68,6] = selecting_data[selecting_data['country'] == 'Montenegro']['dsp_inc50']

# Bosnia and Herzegovina
data_frame.iloc[69:84,6] = selecting_data[selecting_data['country'] == 'Bosnia and Herzegovina']['dsp_inc50']

# Croatia
data_frame.iloc[85:102,6] = selecting_data[selecting_data['country'] == 'Croatia']['dsp_inc50']

# Slovenia
data_frame.iloc[102:119,6] = selecting_data[selecting_data['country'] == 'Slovenia']['dsp_inc50']

# Bulgaria
data_frame.iloc[119:136,6] = selecting_data[selecting_data['country'] == 'Bulgaria']['dsp_inc50']

# Romania
data_frame.iloc[136:153,6] = selecting_data[selecting_data['country'] == 'Romania']['dsp_inc50']


# SWIID Disposable Income Inequality for top 10%

# selecting observations and calculating mean
selecting_data["dsp_inc10"] = selecting_data.iloc[:, 93:103].mean(axis=1)
# adding new variable with NaN values
data_frame["swiid_dsp_top10"] = np.nan

# Albania
data_frame.iloc[0:17,7] = selecting_data[selecting_data['country'] == 'Albania']['dsp_inc10']

# North Macedonia
data_frame.iloc[17:34,7] = selecting_data[selecting_data['country'] == 'North Macedonia']['dsp_inc10']

# Serbia
data_frame.iloc[34:51,7] = selecting_data[selecting_data['country'] == 'Serbia']['dsp_inc10']

# Montenegro
data_frame.iloc[56:68,7] = selecting_data[selecting_data['country'] == 'Montenegro']['dsp_inc10']

# Bosnia and Herzegovina
data_frame.iloc[69:84,7] = selecting_data[selecting_data['country'] == 'Bosnia and Herzegovina']['dsp_inc10']

# Croatia
data_frame.iloc[85:102,7] = selecting_data[selecting_data['country'] == 'Croatia']['dsp_inc10']

# Slovenia
data_frame.iloc[102:119,7] = selecting_data[selecting_data['country'] == 'Slovenia']['dsp_inc10']

# Bulgaria
data_frame.iloc[119:136,7] = selecting_data[selecting_data['country'] == 'Bulgaria']['dsp_inc10']

# Romania
data_frame.iloc[136:153,7] = selecting_data[selecting_data['country'] == 'Romania']['dsp_inc10']
# Out:
# C:\Users\haris\AppData\Local\Temp\ipykernel_40720\3822764090.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   selecting_data["mrkt_inc"] = selecting_data.iloc[:, 104:204].mean(axis=1)
# C:\Users\haris\AppData\Local\Temp\ipykernel_40720\3822764090.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selecting_data["mrkt_inc"] = selecting_data.iloc[:, 104:204].mean(axis=1)
# ...

# %%
# Dependent variable Gini Coefficients UNU WIDER

# loading the Wilder data
wilder = pd.read_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/wiid_income_inequality.xlsx")

# selecting observations and years
selecting_data1 = wilder[wilder['COUNTRY'].isin(balkan_countries) & (wilder['YEAR'] >= 2000) & (wilder['YEAR'] <= 2016)]

# adding new variable with NaN
data_frame["gini_coeff"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Albania']['GINI INDEX'])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'North Macedonia']['GINI INDEX'])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Serbia']['GINI INDEX'])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Montenegro']['GINI INDEX'])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Bosnia and Herzegovina']['GINI INDEX'])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Croatia']['GINI INDEX'])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Slovenia']['GINI INDEX'])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Bulgaria']['GINI INDEX'])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Romania']['GINI INDEX'])

#for country in balkan_countries:
        #data_frame.loc[data_frame['Country'] == country, 'Gini_coeff'] = list(selecting_data1[selecting_data1['COUNTRY'] == country]['GINI INDEX'])


# Dependent Variable S80/S20

# adding new variable with NaN
data_frame["s80s20"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Albania']['S80S20'])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'North Macedonia']['S80S20'])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Serbia']['S80S20'])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Montenegro']['S80S20'])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Bosnia and Herzegovina']['S80S20'])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Croatia']['S80S20'])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Slovenia']['S80S20'])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Bulgaria']['S80S20'])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 's80s20'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Romania']['S80S20'])


# Dependent Variable Palma Ratio

# new variable with NaN values
data_frame["palma"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'palma'] = list(selecting_data1.loc[selecting_data1['COUNTRY'] == 'Albania', 'PALMA '])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'North Macedonia']['PALMA '])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Serbia']['PALMA '])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Montenegro']['PALMA '])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Bosnia and Herzegovina']['PALMA '])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Croatia']['PALMA '])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Slovenia']['PALMA '])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Bulgaria']['PALMA '])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'palma'] = list(selecting_data1[selecting_data1['COUNTRY'] == 'Romania']['PALMA '])

# %%
print(selecting_data1.columns)
# Out:
# Index(['ISO', 'COUNTRY', 'YEAR', 'GINI INDEX', 'S80S20', 'PALMA '], dtype='object')

# %%
# Independent Variable Financial Liberalization

# loading the financial liberalization indicators
fin_lib = pd.ExcelFile("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/financial_liberalization_indicators.xlsx")

# adding new variable with NaN
data_frame["fin_lib"] = np.nan

# Albania
fin_lib1 = pd.read_excel(fin_lib, 'Albania')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
albania = fin_lib1.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Albania', 'fin_lib'] = list(albania)

# North Macedonia
fin_lib2 = pd.read_excel(fin_lib, 'North Macedonia')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
nmacedonia = fin_lib2.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'North Macedonia', 'fin_lib'] = list(nmacedonia)

# Serbia
fin_lib3 = pd.read_excel(fin_lib, 'Serbia')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
serbia = fin_lib3.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Serbia', 'fin_lib'] = list(serbia)

# Montenegro
fin_lib4 = pd.read_excel(fin_lib, 'Montenegro')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
montenegro = fin_lib4.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Montenegro', 'fin_lib'] = list(montenegro)

# Bosnia and Herzegovina
fin_lib5 = pd.read_excel(fin_lib, 'Bosnia and Herzegovina')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
bh = fin_lib5.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'fin_lib'] = list(bh)

# Croatia
fin_lib6 = pd.read_excel(fin_lib, 'Croatia')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
croatia = fin_lib6.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Croatia', 'fin_lib'] = list(croatia)

# Slovenia
fin_lib7 = pd.read_excel(fin_lib, 'Slovenia')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
slovenia = fin_lib7.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Slovenia', 'fin_lib'] = list(slovenia)

# Bulgaria
fin_lib8 = pd.read_excel(fin_lib, 'Bulgaria')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
bulgaria = fin_lib8.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Bulgaria', 'fin_lib'] = list(bulgaria)

# Romania
fin_lib9 = pd.read_excel(fin_lib, 'Romania')
# extracting the sub-indices 3D, 4C, 4D, 5A and calculating the mean 
romania = fin_lib9.iloc[[26, 35, 36, 42], 15:48:2].mean()
# adding new variable in the initial data frame
data_frame.loc[data_frame['country'] == 'Romania', 'fin_lib'] = list(romania)

# %%
# Independent Variable Global Financial Crisis 2007-2008

# creating dummy variable indicating the global financial crisis
data_frame["gfc"] = np.zeros(len(data_frame)).astype(int)
data_frame.loc[data_frame['year'].isin([2007, 2008]), 'gfc'] = 1

# %%
# Independent Variable Financial Development

# Private Credit/GDP
# loading the financial development indicator data
fin_dev_prcrdt = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/financial_development_indicator.csv")

# adding variable with NaN
data_frame["fin_dev_prcrdt"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'ALB'].iloc[0,12:29])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'MKD'].iloc[0,12:29])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'SRB'].iloc[0,12:29])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'MNE'].iloc[0,12:29].replace('..', np.nan))

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'BIH'].iloc[0,12:29])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'HRV'].iloc[0,12:29].replace('..', np.nan))

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'SVN'].iloc[0,12:29].replace('..', np.nan))

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'BGR'].iloc[0,12:29].replace('..', np.nan))

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'fin_dev_prcrdt'] = list(fin_dev_prcrdt[fin_dev_prcrdt['Country Code'] == 'ROU'].iloc[0,12:29])

# Bank Deposits/GDP
# loading the second financial development indicator data
fin_dev_dep1 = pd.ExcelFile("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/financial_structure_worldbank.xlsx")
fin_dev_dep = pd.read_excel(fin_dev_dep1, 'Data - October 2019')

# adding variable with NaN
data_frame["fin_dev_dep"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Montenegro 
data_frame.loc[data_frame['country'] == 'Montenegro', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Bosnia & Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# %%
# World Bank Development Indicators Control Variables
# IMF Inflation Rate Control Variable for B & H
# UNCTD FDI on Serbia and Montenegro

# loading the world development indicators data
wdi = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/world_bank_control_variables.csv")

# GDP per capita
# new variable with NaN values
data_frame["gdp_per"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'gdp_per'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'GDP per capita (constant 2015 US$)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Trade (% of GDP)
# new variable with NaN values
data_frame["trade"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'trade'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'trade'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'trade'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'trade'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'trade'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'trade'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'trade'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'trade'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'trade'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Trade (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Population
# new variable with NaN values
data_frame["pop"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'pop'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'pop'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'pop'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'pop'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'pop'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'pop'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'pop'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'pop'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'pop'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Population, total')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Inflation
# new variable with NaN values
data_frame["infl"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'infl'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'infl'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'infl'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'infl'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# inserting the values for Serbia from 2000 to 2007
data_frame.loc[(data_frame['country'] == 'Montenegro') & (data_frame['year'].between(2000, 2007)), 'infl'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2007 [YR2007]'].values[0].tolist()

# Bosnia & Herzegovina
# loading the imf data
imf_infl = pd.read_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/b_h_inflation_rate.xls")
# inserting the values
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'infl'] = list(imf_infl.loc[imf_infl['Inflation rate, average consumer prices (Annual percent change)'] == 'Bosnia and Herzegovina'].iloc[0,21:38])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'infl'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'infl'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'infl'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'infl'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Inflation, consumer prices (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['infl'] = data_frame['infl'].replace('..', 'NaN')

# GDP growth (annual %)
# new variable with NaN values
data_frame["gdp_grth"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'gdp_grth'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'GDP growth (annual %)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Agriculture, forestry, and fishing, value added (% of GDP)
# new variable with NaN values
data_frame["agri"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'agri'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'agri'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'agri'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'agri'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'agri'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'agri'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'agri'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'agri'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'agri'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Industry (including construction), value added (% of GDP)
# new variable with NaN values
data_frame["ind"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'ind'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'ind'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'ind'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'ind'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'ind'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'ind'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'ind'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'ind'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'ind'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Industry (including construction), value added (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Total natural resources rents (% of GDP)
# new variable with NaN values
data_frame["nat_res"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'nat_res'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Total natural resources rents (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Adjusted savings: education expenditure (% of GNI)
# new variable with NaN values
data_frame["edu_exp"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'edu_exp'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Adjusted savings: education expenditure (% of GNI)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['edu_exp'] = data_frame['edu_exp'].replace('..', 'NaN')


# School enrollment, primary (% gross)
# new variable with NaN values
data_frame["edu_prime"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

#Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'edu_prime'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'School enrollment, primary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['edu_prime'] = data_frame['edu_prime'].replace('..', 'NaN')


# School enrollment, secondary (% gross)
# new variable with NaN values
data_frame["edu_sec"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'edu_sec'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'School enrollment, secondary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['edu_sec'] = data_frame['edu_sec'].replace('..', 'NaN')


# School enrollment, tertiary (% gross)
# new variable with NaN values
data_frame["edu_ter"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'edu_ter'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'School enrollment, tertiary (% gross)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['edu_ter'] = data_frame['edu_ter'].replace('..', 'NaN')


# Life expectancy at birth, total (years)
# new variable with NaN values
data_frame["life_exp"] = np.nan

#Albania
data_frame.loc[data_frame['country'] == 'Albania', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'life_exp'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Life expectancy at birth, total (years)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Net barter terms of trade index (2015 = 100)
# new variable with NaN values
data_frame["net_barter"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# manually imputing values for Serbia and Montenegro between 2000 and 2006
# barter_sermon = [100,99.01,98.88,99.10,101.33,106.02,111.63,110.42]
# data_frame.loc[(data_frame['country'] == 'Serbia') & (data_frame['year'].between(2000, 2007)), 'net_barter'] = list(barter_sermon)

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# manually imputing values for Serbia and Montenegro
# data_frame.loc[(data_frame['country'] == 'Montenegro') & (data_frame['year'].between(2000, 2007)), 'net_barter'] = list(barter_sermon)

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'net_barter'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Net barter terms of trade index (2015 = 100)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['net_barter'] = data_frame['net_barter'].replace('..', 'NaN')


# Foreign direct investment, net inflows (% of GDP)
# new variable with NaN values
data_frame["fdi"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# loading UNCTAD data on FDI for Serbia and Montenegro
unfctad = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/unctad_fdi_control.csv") 
# inserting the values for Serbia and Montenegro between 2000 and 2006
data_frame.loc[(data_frame['country'] == 'Serbia') & (data_frame['year'].between(2000, 2006)), 'fdi'] = list(unfctad.loc[unfctad["Year"].between(2000,2006),"Percentage_of_Gross_Domestic_Product_Value"])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# inserting the values for Serbia and Montenegro
data_frame.loc[(data_frame['country'] == 'Montenegro') & (data_frame['year'].between(2000, 2006)), 'fdi'] = list(unfctad.loc[unfctad["Year"].between(2000,2006),"Percentage_of_Gross_Domestic_Product_Value"])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'fdi'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Foreign direct investment, net inflows (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['fdi'] = data_frame['fdi'].replace('..', 'NaN')


# Gross fixed capital formation (% of GDP)
# new variable with NaN values
data_frame["cap_for"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'cap_for'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Gross fixed capital formation (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# General government final consumption expenditure (% of GDP)

# new variable with NaN values
data_frame["gvt_cs"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

#Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'gvt_cs'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'General government final consumption expenditure (% of GDP)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()


# Unemployment, total (% of total labor force) (modeled ILO estimate)

# new variable with NaN values
data_frame["unemp"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'ALB') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'MKD') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'SRB') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'MNE') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'BIH') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'HRV') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

#Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'SVN') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'BGR') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'unemp'] = wdi.loc[(wdi['Country Code'] == 'ROU') & (wdi['Series Name'] == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Changing the values to interger values
data_frame["unemp"] = data_frame["unemp"].str.replace(",", ".").astype(float)

# %%
# Control Dummy Variable for Currency Crisis (data taken from Laeven and Valencia)

# new variable with zero values
data_frame["curcri"] = np.zeros(len(data_frame)).astype(int)
# indicating the currency crisis in Serbia for the year 2000
data_frame.loc[(data_frame['year'] == 2000) & (data_frame['country'] == 'Serbia'), 'curcri'] = 1
data_frame.loc[(data_frame['year'] == 2000) & (data_frame['country'] == 'Montenegro'), 'curcri'] = 1

# %%
# Control Variable Capital Openness

# loading the kaopen data
kaopen = pd.read_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/kaopen_2020_control_variables.xlsx")

# new variable with NaN values
data_frame["kaopen"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'ALB') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'MKD') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# Serbia (missing)
# Montenegro (missing)

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'BIH') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'HRV') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'SVN') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'BGR') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'kaopen'] = list(kaopen.loc[(kaopen['ccode'] == 'ROM') & (kaopen['year'] >= 2000) & (kaopen['year'] <= 2016), 'kaopen'])

# %%
# Control Variable Civil Liberties

# reading the civil liberties data
civ_lib1 = pd.ExcelFile("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/civil_liberties_control_variables.xlsx")
civ_lib = pd.read_excel(civ_lib1, 'Country Ratings, Statuses ')

# new variable with NaN values
data_frame["civ_lib"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Albania'].iloc[0, 80:129:3].values

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'North Macedonia'].iloc[0, 80:129:3].values

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Serbia'].iloc[0, 80:129:3].values

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Montenegro'].iloc[0, 80:129:3].values

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Bosnia and Herzegovina'].iloc[0, 80:129:3].values

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Croatia'].iloc[0, 80:129:3].values

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Slovenia'].iloc[0, 80:129:3].values

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Bulgaria'].iloc[0, 80:129:3].values

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'civ_lib'] = civ_lib.loc[civ_lib['Survey Edition'] == 'Romania'].iloc[0, 80:129:3].values

# replacing empty values with NaN
data_frame['civ_lib'] = data_frame['civ_lib'].replace('-','NaN')
# Out:
# Country Ratings, Statuses

# %%
# Control Dummy Variable Executive Party Orientation (left (socialist, communist, etc.) indicated as 1)

# reading the executive party orientation data
exprty = pd.read_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/executive_party_orientation_control_variables.xlsx")

# new variable with NaN values
data_frame["exprty"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'ALB') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), ('1','0','0', 'NaN')))

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'MKD') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

# Serbia # Montenegro (under Federalist Republic of Yugoslavia)
data_frame.loc[data_frame['country'] == 'Serbia', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'YSR') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

data_frame.loc[data_frame['country'] == 'Montenegro', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'YSR') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

# Bosnia and Herzegovina (missing)

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'HRV') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'SVN') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'BGR') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'exprty'] = list(exprty.loc[(exprty['ifs'] == 'ROM') & (exprty['year'] >= '2000-01-01') & (exprty['year'] <= '2016-01-01'), 'execrlc'].replace(('Left', 'Right', 'Center', '-999'), (1,0,0, 'NaN')))

# %%
# Control Variable Trade Globalization

# loading the data
trade_res = pd.read_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/KOFGI_2023_public.xlsx")

# new variable with NaN values
data_frame["trade_glob"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Albania') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'North Macedonia') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Serbia') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Montenegro') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Bosnia and Herzegovina') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Croatia') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Slovenia') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Bulgaria') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'trade_glob'] = list(trade_res.loc[(trade_res['country'] == 'Romania') & (trade_res['year'].between(2000,2016)), 'KOFTrGIdj'])

# %%
# Legal Origin Dummies (data from Rafael La Porta)

# loading the government ownership of banks data 
leg_org1 = pd.ExcelFile("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/govt_ownership_banks.xls")
leg_org = pd.read_excel(leg_org1, 'data')

# new variables with NaN values
# dummy variable for socialist law legal origin 
data_frame["legor_so"] = np.zeros(len(data_frame)).astype(int)
# dummy variable for german law legal origin
data_frame["legor_ge"] = np.zeros(len(data_frame)).astype(int)

# Albania 
data_frame.loc[data_frame['country'] == 'Albania', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'albania', 'legor_so'].values[0].astype(int)

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'macedonia (fmr.yu', 'legor_so'].values[0].astype(int)

# Serbia (values missing in original data set for the time period prior to Yugoslavia however it is assumed german law legal origin) (paper 'Law and Finance' by LaPorta)
data_frame.loc[data_frame['country'] == 'Serbia', 'legor_ge'] = 1

# Montenegro (similar to Serbia)
data_frame.loc[data_frame['country'] == 'Montenegro', 'legor_ge'] = 1

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'bosnia and herzeg', 'legor_so'].values[0].astype(int)

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'croatia', 'legor_so'].values[0].astype(int)

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'slovenia', 'legor_so'].values[0].astype(int)

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'bulgaria', 'legor_so'].values[0].astype(int)

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'legor_so'] = leg_org.loc[leg_org['contcode'] == 'romania', 'legor_so'].values[0].astype(int)

# %%
# Descriptive Statistics for Structure of Financial Markets in South Eastern Europe

# Private Credit by Deposit Money Banks to GDP (%)
# new variable with NaN values
data_frame["bank_prcrdt"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])


# Private Credit by Deposit Money Banks and Other Financial Institutions to GDP (%)
# new variable with NaN values
data_frame["all_prcrdt"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])


# Share of Banking Sector in Private Credit to GDP (%)
data_frame["bank_share_prcrdt"] = ((data_frame['bank_prcrdt']/data_frame['all_prcrdt'])*100).round(decimals=0).astype('Int64')


# Deposit Money Bank Assets to GDP (%)
# new vairable with NaN values
data_frame["bank_asgdp"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])


# Financial System Deposits to GDP (%)
# new variable with NaN values
data_frame["fin_dep"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])


# Share of Banking Sector in Deposits to GDP (%)
data_frame["bank_share_dep"] = ((data_frame['fin_dev_dep']/data_frame['fin_dep'])*100).round(decimals=0).astype('Int64')


# Net Interest Margin (%)
# new variable with NaN values
data_frame["net_int"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'NET INTEREST MARGIN (%)'].iloc[40:57])


# Bank ROA (return on assets)
# new variable with NaN values
data_frame["bank_roa"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'BANK ROA'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'BANK ROA'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'BANK ROA'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'BANK ROA'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'BANK ROA'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'BANK ROA'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'BANK ROA'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'BANK ROA'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'BANK ROA'].iloc[40:57])


# Bank ROE (return on equity)
# new variable with NaN values
data_frame["bank_roe"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'BANK ROE'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'BANK ROE'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'BANK ROE'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'BANK ROE'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'BANK ROE'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'BANK ROE'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'BANK ROE'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'BANK ROE'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'BANK ROE'].iloc[40:57])


# Bank Concentration (assets of three largest banks as a share of assets of all commercial banks)
# new variable with NaN values
data_frame["bank_con"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'BANK CONCENTRATION (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'BANK CONCENTRATION (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'bank_con'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'BANK CONCENTRATION (%)'].iloc[40:57])


# Non-Banking Sector (Insurance Companies)

# Insurance Company Assets to GDP (%)
# loading the insurance company assets to GDP data
ins_ass = pd.read_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/insurance_company_assets_gdp.xlsx")

# new variable with NaN values
data_frame["ins_asset"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Albania'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'North Macedonia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Serbia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Montenegro'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Bosnia and Herzegovina'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Croatia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Slovenia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Romania'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Bulgaria'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['ins_asset'] = data_frame['ins_asset'].replace('..', 'NaN')
# transforming into float values
data_frame['ins_asset'] = data_frame['ins_asset'].astype(float)

# Life Insurance Premium Volume to GDP (%)
# new variable with NaN values
data_frame["life_ins"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])


# Non-Life Insurance Premium Volume to GDP(%)
# new variable with NaN values
data_frame["nonlife_ins"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])


# Stock Market
# Stock Market Capitalization to GDP (%)
# new variable with NaN values
data_frame["stock_mrkt"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Stock Market Total Value Traded to GDP
# new variable with NaN values
data_frame["stock_trade"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ALB', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MKD', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SRB', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MNE', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BIH', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'HRV', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SVN', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BGR', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ROU', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])


# Private and Pensions Funds
# Private Pension Funds Assets
# loading the data
private_fund = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/private_pension_fund_assets.csv")

# new variable with NaN values
data_frame["private_penfunds"] = np.nan

# Albania
data_frame.loc[(data_frame['country'] == 'Albania') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'ALB') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# North Macedonia
data_frame.loc[(data_frame['country'] == 'North Macedonia') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'MKD') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# Serbia
data_frame.loc[(data_frame['country'] == 'Serbia') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'SRB') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# Montenegro
# Bosnia and Herzegovina

# Croatia
data_frame.loc[(data_frame['country'] == 'Croatia') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'HRV') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# Slovenia
data_frame.loc[(data_frame['country'] == 'Slovenia') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'SVN') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# Bulgaria
data_frame.loc[(data_frame['country'] == 'Bulgaria') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'BGR') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# Romania
data_frame.loc[(data_frame['country'] == 'Romania') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'ROU') & (private_fund['TIME'].between(2007,2016)), 'Value'])


# Mutual Fund Assets to GDP
# loading the World Bank data
mutual_fund_assets = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/mutual_fund_assets.csv")

# new variable with NaN values
data_frame["mutual_funds"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Albania'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'North Macedonia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Serbia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Montenegro'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Bosnia and Herzegovina'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Croatia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Slovenia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Bulgaria'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Romania'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing empty values with NaN
data_frame['mutual_funds'] = data_frame['mutual_funds'].replace('..', 'NaN')
# transforming into float values
data_frame['mutual_funds'] = data_frame['mutual_funds'].astype(float)


# International Capital Flows
# Foreign direct investment, net inflows (BoP, current US$)

# loading the data set
capital_flows_dollar = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/international_capital_flows.csv")

# new variable with NaN values
data_frame["fdi_dollar"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Albania'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'North Macedonia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Serbia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Montenegro'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Bosnia and Herzegovina'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Croatia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Slovenia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Bulgaria'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'fdi_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Romania'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[1].tolist()

# replacing empty values with NaN
data_frame['fdi_dollar'] = data_frame['fdi_dollar'].replace('..', 'NaN')
# transforming into float values
data_frame['fdi_dollar'] = data_frame['fdi_dollar'].astype(float)


# Portfolio equity, net inflows (BoP, current US$)

# new variable with NaN values
data_frame["equity_dollar"] = np.nan

# Albania
data_frame.loc[data_frame['country'] == 'Albania', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Albania'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# North Macedonia
data_frame.loc[data_frame['country'] == 'North Macedonia', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'North Macedonia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Serbia
data_frame.loc[data_frame['country'] == 'Serbia', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Serbia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Montenegro
data_frame.loc[data_frame['country'] == 'Montenegro', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Montenegro'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bosnia and Herzegovina
data_frame.loc[data_frame['country'] == 'Bosnia and Herzegovina', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Bosnia and Herzegovina'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Croatia
data_frame.loc[data_frame['country'] == 'Croatia', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Croatia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Slovenia
data_frame.loc[data_frame['country'] == 'Slovenia', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Slovenia'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Bulgaria
data_frame.loc[data_frame['country'] == 'Bulgaria', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Bulgaria'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Romania
data_frame.loc[data_frame['country'] == 'Romania', 'equity_dollar'] = capital_flows_dollar.loc[capital_flows_dollar['Country Name'] == 'Romania'].loc[:,'2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing empty values with NaN
data_frame['equity_dollar'] = data_frame['equity_dollar'].replace('..', 'NaN')
# transforming into float values
data_frame['equity_dollar'] = data_frame['equity_dollar'].astype(float)

#print(data_frame.to_string())

# %%
# Final Data Formatting

# Changing the values from object to float
# selecting the variables from 'fin_dev', to 'gvt_cs'
columns_to_convert = data_frame.loc[:, 'fin_dev_prcrdt':'gvt_cs'].columns
# changing the numeric values to float 
data_frame[columns_to_convert] = data_frame[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# Changing the values from object to integer
# selecting the variables
columns_to_convert1 = ['civ_lib', 'exprty']
# changing the numeric values to integer
for column in columns_to_convert1:
    data_frame[column] = pd.to_numeric(data_frame[column], errors='coerce')
    data_frame[column] = data_frame[column].fillna(0).astype(int)

# Rounding the decimal points
data_frame = data_frame.round(3)

# Saving the data in csv and stata format
# csv format
data_frame.to_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/final_data/final_data_see.csv")
# stata format
data_frame.to_stata("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/final_data/final_data_see.dta")
