# %%
######### Data Management File 1 #########

# Data Descriptive Statistics of Structure of Financial Markets in Different Regions

# %%
# Packages used

import numpy as np
import pandas as pd

# %%
# Indicator variables

# empty data frame
data_frame = pd.DataFrame()

# defining the countries of interest
countries = ["United States of America", "Canada", "Mexico", "Brazil", "Argentina", "Cuba", "United Kingdom", "Germany", "Turkey", "Saudi Arabia", "United Arab Emirates", "Egypt", "South Africa", "Nigeria","Kenya","India","Indonesia","Singapore","China","Japan","Australia"]

# indicator variables (country, year)
data_frame["country"] = np.repeat(countries,17)
data_frame["year"] = np.tile(range(2000,2017),21).astype(int)

# %%
# Banking Sector in Different Regions of the World

# Bank Deposits/GDP
# loading the data
fin_dev_dep1 = pd.ExcelFile("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/financial_structure_worldbank.xlsx")
fin_dev_dep = pd.read_excel(fin_dev_dep1, 'Data - October 2019')

# adding variable with NaN
data_frame["fin_dev_dep"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])


## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'fin_dev_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'BANK DEPOSITS to GDP (%)'].iloc[40:57])


# Financial System Deposits to GDP (%)
# new variable with NaN values
data_frame["fin_dep"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'fin_dep'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'FINANCIAL SYSTEM DEPOSITS to GDP (%)'].iloc[40:57])


# Share of Banking Sector in Deposits to GDP (%)
data_frame["bank_share_dep"] = ((data_frame['fin_dev_dep']/data_frame['fin_dep'])*100).round(decimals=0).astype('Int64')


# Private Credit by Deposit Money Banks to GDP (%)
# new variable with NaN values
data_frame["bank_prcrdt"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'bank_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS to GDP (%)'].iloc[40:57])


# Private Credit by Deposit Money Banks and Other Financial Institutions to GDP (%)
# new variable with NaN values
data_frame["all_prcrdt"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

## Latin America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'all_prcrdt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'PRIVATE CREDIT BY DEPOSIT MONEY BANKS AND OTHER FINANCIAL INSTITUTIONS to GDP (%)'].iloc[40:57])


# Share of Banking Sector in Private Credit to GDP (%)
data_frame["bank_share_prcrdt"] = ((data_frame['bank_prcrdt']/data_frame['all_prcrdt'])*100).round(decimals=0).astype('Int64')


# Deposit Money Bank Assets to GDP (%)
# new vairable with NaN values
data_frame["bank_asgdp"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

## Latin America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'bank_asgdp'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'DEPOSIT MONEY BANK ASSETS to GDP (%)'].iloc[40:57])


# Net Interest Margin (%)
# new variable with NaN values
data_frame["net_int"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'NET INTEREST MARGIN (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'NET INTEREST MARGIN (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'NET INTEREST MARGIN (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'NET INTEREST MARGIN (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'NET INTEREST MARGIN (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'NET INTEREST MARGIN (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'NET INTEREST MARGIN (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'NET INTEREST MARGIN (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'NET INTEREST MARGIN (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'net_int'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'NET INTEREST MARGIN (%)'].iloc[40:57])


# Bank ROA (return on assets)
# new variable with NaN values
data_frame["bank_roa"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'BANK ROA'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'BANK ROA'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'BANK ROA'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'BANK ROA'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'BANK ROA'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'BANK ROA'].iloc[40:57])


## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'BANK ROA'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'BANK ROA'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'BANK ROA'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'BANK ROA'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'BANK ROA'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'BANK ROA'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'BANK ROA'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'BANK ROA'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'BANK ROA'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'BANK ROA'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'BANK ROA'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'BANK ROA'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'BANK ROA'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'BANK ROA'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'bank_roa'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'BANK ROA'].iloc[40:57])


# Bank ROE (return on equity)
# new variable with NaN values
data_frame["bank_roe"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'BANK ROE'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'BANK ROE'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'BANK ROE'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'BANK ROE'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'BANK ROE'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'BANK ROE'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'BANK ROE'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'BANK ROE'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'BANK ROE'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'BANK ROE'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'BANK ROE'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'BANK ROE'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'BANK ROE'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'BANK ROE'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'BANK ROE'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'BANK ROE'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'BANK ROE'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'BANK ROE'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'BANK ROE'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'BANK ROE'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'bank_roe'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'BANK ROE'].iloc[40:57])


# Non-Banking Sector (Insurance Companies)

# Insurance Company Assets to GDP (%)
# loading the insurance company assets to GDP data
ins_ass = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/insurance_company_assets_gdp_world.csv")

# new variable with NaN values
data_frame["ins_asset"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'United States'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Canada'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Mexico'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Brazil'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Argentina'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Cuba'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'United Kingdom'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Germany'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Turkey'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Saudi Arabia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'United Arab Emirates'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Egypt, Arab Rep.'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'South Africa'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Nigeria'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Kenya'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'India'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Indonesia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Singapore'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'China'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Japan'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'ins_asset'] = ins_ass.loc[ins_ass['Country Name'] == 'Australia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing missing values with NaN
data_frame['ins_asset'] = data_frame['ins_asset'].replace('..', 'NaN')
# transforming into float values
data_frame['ins_asset'] = data_frame['ins_asset'].astype(float)


# Life Insurance Premium Volume to GDP (%)
# new variable with NaN values
data_frame["life_ins"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'life_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])


# Non-Life Insurance Premium Volume to GDP(%)
# new variable with NaN values
data_frame["nonlife_ins"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'nonlife_ins'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'NON-LIFE INSURANCE PREMIUM VOLUME to GDP (%)'].iloc[40:57])

# Stock Market
# Stock Market Capitalization to GDP (%)
# new variable with NaN values
data_frame["stock_mrkt"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'stock_mrkt'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'STOCK MARKET CAPITALIZATION to GDP (%)'].iloc[40:57])


# Stock Market Total Value Traded to GDP
# new variable with NaN values
data_frame["stock_trade"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'USA', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CAN', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'MEX', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'BRA', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARG', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CUB', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'GBR', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'DEU', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'TUR', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SAU', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ARE', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'EGY', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'ZAF', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'NGA', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'KEN', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IND', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'IDN', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'SGP', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'CHN', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'JPN', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'stock_trade'] = list(fin_dev_dep.loc[fin_dev_dep['WB COUNTRY CODE'] == 'AUS', 'STOCK MARKET TOTAL VALUE TRADED to GDP (%)'].iloc[40:57])


# Private and Pensions Funds
# Private Pension Funds Assets
# loading the data
private_fund = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/private_pension_fund_assets_world.csv")

# new variable with NaN values
data_frame["private_penfunds"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'USA') & (private_fund['TIME'].between(2000,2016)), 'Value'])

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'CAN') & (private_fund['TIME'].between(2000,2016)), 'Value'])

# Mexico
data_frame.loc[(data_frame['country'] == 'Mexico') & (data_frame['year'].between(2001,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'MEX') & (private_fund['TIME'].between(2001,2016)), 'Value'])

## South America and the Caribbean
# Brazil
data_frame.loc[(data_frame['country'] == 'Brazil') & (data_frame['year'] == 2003), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'BRA') & (private_fund['TIME'] == 2003), 'Value'])
data_frame.loc[(data_frame['country'] == 'Brazil') & (data_frame['year'].between(2006,2007)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'BRA') & (private_fund['TIME'].between(2006,2007)), 'Value'])
data_frame.loc[(data_frame['country'] == 'Brazil') & (data_frame['year'].between(2014,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'BRA') & (private_fund['TIME'].between(2014,2016)), 'Value'])

# Argentina
data_frame.loc[(data_frame['country'] == 'Argentina') & (data_frame['year'].between(2002,2007)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'ARG') & (private_fund['TIME'].between(2002,2007)), 'Value'])

# Cuba (missing data)

## Europe and West Asia
# United Kingdom
data_frame.loc[(data_frame['country'] == 'United Kingdom') & (data_frame['year'].between(2001,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'GBR') & (private_fund['TIME'].between(2001,2016)), 'Value'])

# Germany
data_frame.loc[(data_frame['country'] == 'Germany') & (data_frame['year'].between(2000,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'DEU') & (private_fund['TIME'].between(2000,2016)), 'Value'])

# Turkey
data_frame.loc[(data_frame['country'] == 'Turkey') & (data_frame['year'].between(2004,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'TUR') & (private_fund['TIME'].between(2004,2016)), 'Value'])

## Middle East and North Africa
# Saudi Arabia (missing data)

# United Arab Emirates (missing data)

# Egypt
data_frame.loc[(data_frame['country'] == 'Egypt') & (data_frame['year'] == 2008), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'EGY') & (private_fund['TIME'] == 2008), 'Value'])
data_frame.loc[(data_frame['country'] == 'Egypt') & (data_frame['year'].between(2013,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'EGY') & (private_fund['TIME'].between(2013,2016)), 'Value'])

## Sub-Saharan Africa
# South Africa
data_frame.loc[(data_frame['country'] == 'South Africa') & (data_frame['year'].between(2001,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'ZAF') & (private_fund['TIME'].between(2001,2016)), 'Value'])

# Nigeria
data_frame.loc[(data_frame['country'] == 'Nigeria') & (data_frame['year'].between(2007,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'NGA') & (private_fund['TIME'].between(2007,2016)), 'Value'])

# Kenya
data_frame.loc[(data_frame['country'] == 'Kenya') & (data_frame['year'].between(2001,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'KEN') & (private_fund['TIME'].between(2001,2016)), 'Value'])

## South Asia
# India
data_frame.loc[(data_frame['country'] == 'India') & (data_frame['year'] == 2003), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'IND') & (private_fund['TIME'] == 2003), 'Value'])
data_frame.loc[(data_frame['country'] == 'India') & (data_frame['year'].between(2011,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'IND') & (private_fund['TIME'].between(2011,2016)), 'Value'])

# Indonesia
data_frame.loc[(data_frame['country'] == 'Indonesia') & (data_frame['year'].between(2001,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'IDN') & (private_fund['TIME'].between(2001,2016)), 'Value'])

# Singapore
data_frame.loc[(data_frame['country'] == 'Singapore') & (data_frame['year'].between(2011,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'SGP') & (private_fund['TIME'].between(2011,2016)), 'Value'])

## East Asia and Pacific
# China
data_frame.loc[(data_frame['country'] == 'China') & (data_frame['year'].between(2004,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'CHN') & (private_fund['TIME'].between(2004,2016)), 'Value'])

# Japan
data_frame.loc[(data_frame['country'] == 'Japan') & (data_frame['year'].between(2001,2005)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'JPN') & (private_fund['TIME'].between(2001,2005)), 'Value'])
data_frame.loc[(data_frame['country'] == 'Japan') & (data_frame['year'].between(2011,2014)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'JPN') & (private_fund['TIME'].between(2011,2014)), 'Value'])

# Australia
data_frame.loc[(data_frame['country'] == 'Australia') & (data_frame['year'].between(2001,2016)), 'private_penfunds'] = list(private_fund.loc[(private_fund['LOCATION'] == 'AUS') & (private_fund['TIME'].between(2001,2016)), 'Value'])


# Mutual Fund Assets to GDP
# loading the World Bank data
mutual_fund_assets = pd.read_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/mutual_fund_assets_world.csv")

# new variable with NaN values
data_frame["mutual_funds"] = np.nan

## North America
# United States of America
data_frame.loc[data_frame['country'] == 'United States of America', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'United States'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Canada
data_frame.loc[data_frame['country'] == 'Canada', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Canada'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Mexico
data_frame.loc[data_frame['country'] == 'Mexico', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Mexico'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## South America and the Caribbean
# Brazil
data_frame.loc[data_frame['country'] == 'Brazil', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Brazil'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Argentina
data_frame.loc[data_frame['country'] == 'Argentina', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Argentina'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Cuba
data_frame.loc[data_frame['country'] == 'Cuba', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Cuba'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## Europe and West Asia
# United Kingdom
data_frame.loc[data_frame['country'] == 'United Kingdom', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'United Kingdom'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Germany
data_frame.loc[data_frame['country'] == 'Germany', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Germany'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Turkey
data_frame.loc[data_frame['country'] == 'Turkey', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Turkey'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## Middle East and North Africa
# Saudi Arabia
data_frame.loc[data_frame['country'] == 'Saudi Arabia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Saudi Arabia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# United Arab Emirates
data_frame.loc[data_frame['country'] == 'United Arab Emirates', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'United Arab Emirates'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Egypt
data_frame.loc[data_frame['country'] == 'Egypt', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Egypt, Arab Rep.'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## Sub-Saharan Africa
# South Africa
data_frame.loc[data_frame['country'] == 'South Africa', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'South Africa'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Nigeria
data_frame.loc[data_frame['country'] == 'Nigeria', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Nigeria'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Kenya
data_frame.loc[data_frame['country'] == 'Kenya', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Kenya'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## South Asia
# India
data_frame.loc[data_frame['country'] == 'India', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'India'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Indonesia
data_frame.loc[data_frame['country'] == 'Indonesia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Indonesia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# Singapore
data_frame.loc[data_frame['country'] == 'Singapore', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Singapore'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

## East Asia and Pacific
# China
data_frame.loc[data_frame['country'] == 'China', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'China'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# Japan
data_frame.loc[data_frame['country'] == 'Japan', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Japan'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()
# Australia
data_frame.loc[data_frame['country'] == 'Australia', 'mutual_funds'] = mutual_fund_assets.loc[mutual_fund_assets['Country Name'] == 'Australia'].loc[:, '2000 [YR2000]':'2016 [YR2016]'].values[0].tolist()

# replacing empty values with NaN
data_frame['mutual_funds'] = data_frame['mutual_funds'].replace('..', 'NaN')
# transforming into float values
data_frame['mutual_funds'] = data_frame['mutual_funds'].astype(float)

#print(data_frame.to_string())

# %%
# Rounding the decimal points
data_frame = data_frame.round(3)

# Saving the data in csv and stata format
# csv format
data_frame.to_csv("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/final_data/final_data_world.csv")
# stata format
data_frame.to_stata("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/final_data/final_data_world.dta")
# excel format
data_frame.to_excel("C:/Users/haris/OneDrive/Desktop/Master Thesis/Data/final_data/final_data_world.xlsx")
